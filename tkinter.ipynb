# %% [markdown]
# ボタンのグリッド配置テスト

# %%
# -*- coding: utf-8 -*-
from tkinter import *

root = Tk()

def Confirm_click():
    # ボタンがクリックされたときの処理
    print("Confirm button clicked")

columnB = 0
conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=0, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=1, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=2, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=3, column = columnB)

columnB = 1
conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=0, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=1, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=2, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=3, column = columnB)


columnB = 4
conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=0, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=1, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=2, column = columnB)

conf_button = Button(text="Confirm", command=Confirm_click, width=10, height=2)
conf_button.grid(row=3, column = columnB)


root.mainloop()

# %% [markdown]
# 画面切り替えテスト

# %%
import tkinter as tk

class SampleApp:
    def __init__(self, root):
        self.root = root
        self.root.title("画面遷移サンプル")

        # 最初の画面の作成
        self.frame1 = tk.Frame(self.root)
        self.frame1.pack()

        self.start_button = tk.Button(self.frame1, text="Start", command=self.show_second_frame)
        self.start_button.pack(pady=10)

        # 二番目の画面の作成
        self.frame2 = tk.Frame(self.root)
        self.label = tk.Label(self.frame2, text="2番目の画面です")
        self.label.pack(pady=10)

        self.back_button = tk.Button(self.frame2, text="Back", command=self.show_first_frame)
        self.back_button.pack(pady=10)

        # 最初に表示する画面を設定
        self.show_first_frame()

    def show_first_frame(self):
        # 二番目の画面を隠し、最初の画面を表示
        self.frame2.pack_forget()
        self.frame1.pack()

    def show_second_frame(self):
        # 最初の画面を隠し、二番目の画面を表示
        self.frame1.pack_forget()
        self.frame2.pack()

if __name__ == "__main__":
    root = tk.Tk()
    app = SampleApp(root)
    root.mainloop()

# %%
import tkinter as tk

class SampleApp:
    def __init__(self, root):
        self.root = root
        self.root.title("画面遷移サンプル")

        # 最初の画面の作成
        self.frame1 = tk.Frame(self.root)
        self.frame1.grid(row=0, column=0, sticky="nsew")

        self.start_button = tk.Button(self.frame1, text="Start", command=self.show_second_frame)
        self.start_button.pack(pady=10)

        # 二番目の画面の作成
        self.frame2 = tk.Frame(self.root)
        self.label = tk.Label(self.frame2, text="2番目の画面です")
        self.label.pack(pady=10)

        self.back_button = tk.Button(self.frame2, text="Back", command=self.show_first_frame)
        self.back_button.pack(pady=10)

        # グリッドの設定
        self.root.grid_rowconfigure(0, weight=1)
        self.root.grid_columnconfigure(0, weight=1)

        # 最初に表示する画面を設定
        self.show_first_frame()

    def show_first_frame(self):
        # 二番目の画面を隠し、最初の画面を表示
        self.frame2.grid_forget()
        self.frame1.grid(row=0, column=0, sticky="nsew")

    def show_second_frame(self):
        # 最初の画面を隠し、二番目の画面を表示
        self.frame1.grid_forget()
        self.frame2.grid(row=0, column=0, sticky="nsew")

if __name__ == "__main__":
    root = tk.Tk()
    app = SampleApp(root)
    root.mainloop()

# %%
import tkinter as tk

class SampleApp:
    def __init__(self, root):
        self.root = root
        self.root.title("画面遷移サンプル")

        # 画面ごとのフレームを作成
        self.frames = {}
        for btn_text in "ABCDEFG":
            frame = tk.Frame(self.root)
            label = tk.Label(frame, text=f"{btn_text}の画面です")
            label.pack(pady=10)

            back_button = tk.Button(frame, text="Back", command=self.show_first_frame)
            back_button.pack(pady=10)

            self.frames[btn_text] = frame

        # ボタンを作成
        self.buttons = []
        for btn_text, frame in self.frames.items():
            button = tk.Button(self.root, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_frame(btn))
            button.pack(pady=5)
            self.buttons.append(button)

        # 最初に表示する画面を設定
        self.show_first_frame()

    def show_first_frame(self):
        # すべてのフレームを隠し、最初の画面を表示
        for frame in self.frames.values():
            frame.pack_forget()
        for button in self.buttons:
            button.pack()
        self.frames["A"].pack()

    def show_frame(self, btn_text):
        # すべてのフレームを隠し、対応する画面を表示
        for frame in self.frames.values():
            frame.pack_forget()
        for button in self.buttons:
            button.pack()
        self.frames[btn_text].pack()

if __name__ == "__main__":
    root = tk.Tk()
    app = SampleApp(root)
    root.mainloop()

# %%
import tkinter as tk

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理（今回はボタンが押された旨を表示）
        print(f"ボタン{btn_text}が押されました。")

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %%
import tkinter as tk

class WindowA:
    def __init__(self, master, start_page):
        self.master = master
        self.start_page = start_page
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ラベルを配置
        label = tk.Label(self.master, text="画面Aです")
        label.pack(pady=10)

        # ボタンを配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.pack(pady=10)

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self)

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %% [markdown]
# 画面Aの中を作りこんでいく

# %%
import tkinter as tk

class WindowA:
    def __init__(self, master, start_page):
        self.master = master
        self.start_page = start_page
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを配置
        button_texts = ["問題1", "問題2", "問題3", "問題4", "問題5"]
        for i, btn_text in enumerate(button_texts, start=1):
            button = tk.Button(self.master, text=btn_text, command=lambda btn=btn_text: self.show_question(btn))
            button.grid(row=0, column=i-1, padx=10, pady=10, sticky="nsew")

        # グリッドの設定
        for i in range(5):
            self.master.columnconfigure(i, weight=1)

        # ラベルを配置
        label = tk.Label(self.master, text="画面Aです")
        label.grid(row=1, column=0, columnspan=5, pady=10)

        # 戻るボタンを配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.grid(row=2, column=0, columnspan=5, pady=10)

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

    def show_question(self, question):
        # 問題ボタンが押されたときの処理
        print(f"問題{question}が選択されました。")

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self)

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %% [markdown]
# 画面Aの中の問題ボタンに機能を持たせる

# %%
import tkinter as tk

class WindowA:
    def __init__(self, master, start_page):
        self.master = master
        self.start_page = start_page
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # 問題ボタンを配置
        button_texts = ["問題1", "問題2", "問題3", "問題4", "問題5"]
        self.buttons = []
        for i, btn_text in enumerate(button_texts, start=1):
            button = tk.Button(self.master, text=btn_text, command=lambda btn=btn_text: self.show_question(btn))
            button.grid(row=0, column=i-1, padx=10, pady=10, sticky="nsew")
            self.buttons.append(button)

        # グリッドの設定
        for i in range(5):
            self.master.columnconfigure(i, weight=1)

        # ラベルを配置
        self.label_var = tk.StringVar()
        self.label_var.set("画面Aです")
        label = tk.Label(self.master, textvariable=self.label_var)
        label.grid(row=1, column=0, columnspan=5, pady=10)

        # 戻るボタンを配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.grid(row=2, column=0, columnspan=5, pady=10)

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

    def show_question(self, question):
        # 問題ボタンが押されたときの処理
        self.label_var.set(f"問題{question}が選択されました。")
        for btn in self.buttons:
            if btn.cget("text") == question:
                btn.config(state=tk.DISABLED, bg="gray")

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self)

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %% [markdown]
# ボタンAがStart画面で押された場合にStart画面を非表示にする

# %%
import tkinter as tk

class WindowA:
    def __init__(self, master, start_page):
        self.master = master
        self.start_page = start_page
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # 問題ボタンを配置
        button_texts = ["問題1", "問題2", "問題3", "問題4", "問題5"]
        self.buttons = []
        for i, btn_text in enumerate(button_texts, start=1):
            button = tk.Button(self.master, text=btn_text, command=lambda btn=btn_text: self.show_question(btn))
            button.grid(row=0, column=i-1, padx=10, pady=10, sticky="nsew")
            self.buttons.append(button)

        # グリッドの設定
        for i in range(5):
            self.master.columnconfigure(i, weight=1)

        # ラベルを配置
        self.label_var = tk.StringVar()
        self.label_var.set("画面Aです")
        label = tk.Label(self.master, textvariable=self.label_var)
        label.grid(row=1, column=0, columnspan=5, pady=10)

        # 戻るボタンを配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.grid(row=2, column=0, columnspan=5, pady=10)

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

    def show_question(self, question):
        # 問題ボタンが押されたときの処理
        self.label_var.set(f"問題{question}が選択されました。")
        for btn in self.buttons:
            if btn.cget("text") == question:
                btn.config(state=tk.DISABLED, bg="gray")

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            self.master.withdraw()  # Start画面を非表示にする
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self)

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %% [markdown]
# 戻るボタンを少し下に

# %%
import tkinter as tk

class WindowA:
    def __init__(self, master, start_page):
        self.master = master
        self.start_page = start_page
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # 問題ボタンを配置
        button_texts = ["問題1", "問題2", "問題3", "問題4", "問題5"]
        self.buttons = []
        for i, btn_text in enumerate(button_texts, start=1):
            button = tk.Button(self.master, text=btn_text, command=lambda btn=btn_text: self.show_question(btn))
            button.grid(row=0, column=i-1, padx=10, pady=10, sticky="nsew")
            self.buttons.append(button)

        # グリッドの設定
        for i in range(5):
            self.master.columnconfigure(i, weight=1)

        # ラベルを配置
        self.label_var = tk.StringVar()
        self.label_var.set("画面Aです")
        label = tk.Label(self.master, textvariable=self.label_var)
        label.grid(row=1, column=0, columnspan=5, pady=10)

        # 戻るボタンを右下に配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.grid(row=2, column=4, padx=10, pady=50, sticky="se")

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

    def show_question(self, question):
        # 問題ボタンが押されたときの処理
        self.label_var.set(f"問題{question}が選択されました。")
        for btn in self.buttons:
            if btn.cget("text") == question:
                btn.config(state=tk.DISABLED, bg="gray")

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            self.master.withdraw()  # Start画面を非表示にする
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self)

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()

# %% [markdown]
# Excelファイルを表示してみる

# %%
# !pip install openpyxl
# !pip install pywin32
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ------ ------------------------------ 41.0/250.0 kB 991.0 kB/s eta 0:00:01
#      ----------------- -------------------- 112.6/250.0 kB 1.7 MB/s eta 0:00:01
#      ----------------------------- -------- 194.6/250.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.5 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
#close_excel(excel_app, workbook)

# %% [markdown]
# ExcelもWindowサイズを指定してみる

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウの大きさを指定
        excel_app.Width = 1200  # ここを適切な値に変更
        excel_app.Height = 600  # ここを適切な値に変更

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
# close_excel(excel_app, workbook)  # close_excelの呼び出しは必要に応じて行ってください

# %% [markdown]
# 横幅を最大限にしてみる

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウの大きさを画面いっぱいに変更
        excel_app.ActiveWindow.WindowState = 3  # xlMaximized
        excel_app.ActiveWindow.Width = excel_app.Application.Width

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
# close_excel(excel_app, workbook)  # close_excelの呼び出しは必要に応じて行ってください

# %% [markdown]
# 左端に配置

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウの大きさを画面いっぱいに変更
        excel_app.ActiveWindow.WindowState = 3  # xlMaximized
        excel_app.ActiveWindow.Width = excel_app.Application.Width

        # Excelウィンドウを画面の左端に移動
        excel_app.Left = 0

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
# close_excel(excel_app, workbook)  #

# %% [markdown]
# 上の端っこに配置

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウの大きさを画面いっぱいに変更
        excel_app.ActiveWindow.WindowState = 3  # xlMaximized
        excel_app.ActiveWindow.Width = excel_app.Application.Width

        # Excelウィンドウを画面の左上に移動
        excel_app.Left = 0
        excel_app.Top = 0

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
# close_excel(excel_app, workbook)  # close_excelの呼び出しは必要に応じて行ってください

# %% [markdown]
# 高さを5/7に設定してみましょう。

# %%
import win32com.client as win32
import os

def open_excel(file_path):
    # ファイルの存在を確認
    if not os.path.exists(file_path):
        print(f"Error: File '{file_path}' not found.")
        return None

    try:
        # Excelアプリケーションを起動
        excel_app = win32.Dispatch("Excel.Application")

        # Excelファイルを開く
        workbook = excel_app.Workbooks.Open(file_path)

        # Excelウィンドウの大きさを画面いっぱいに変更
        excel_app.ActiveWindow.WindowState = 3  # xlMaximized
        excel_app.ActiveWindow.Width = excel_app.Application.Width
        excel_app.ActiveWindow.Height = excel_app.Application.Height - 30  # タイトルバーなどの高さを考慮

        # Excelウィンドウを画面の左上に移動
        excel_app.Left = 0
        excel_app.Top = 0

        # Excelウィンドウを表示
        excel_app.Visible = True

        return excel_app, workbook

    except Exception as e:
        print(f"Error: {e}")
        return None

def close_excel(excel_app, workbook):
    if workbook is not None:
        try:
            workbook.Close()
        except:
            pass
    if excel_app is not None:
        try:
            excel_app.Quit()
        except:
            pass

# Excelファイルのパスを指定
excel_file_path = r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx"

# Excelを起動してファイルを表示
excel_app, workbook = open_excel(excel_file_path)
# close_excel(excel_app, workbook)  # close_excelの呼び出しは必要に応じて行ってください

# %% [markdown]
# 画面AとExcel画面を統合してみる

# %%
import tkinter as tk
import win32com.client as win32
import os

class WindowA:
    def __init__(self, master, start_page, excel_file_path):
        self.master = master
        self.start_page = start_page
        self.excel_file_path = excel_file_path
        self.master.title("画面A")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を計算
        width = screen_width
        height = int(screen_height * 2 / 7)

        # 画面の下に配置
        x = 0
        y = screen_height - height
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # 問題ボタンを配置
        button_texts = ["問題1", "問題2", "問題3", "問題4", "問題5"]
        self.buttons = []
        for i, btn_text in enumerate(button_texts, start=1):
            button = tk.Button(self.master, text=btn_text, command=lambda btn=btn_text: self.show_question(btn))
            button.grid(row=0, column=i-1, padx=10, pady=10, sticky="nsew")
            self.buttons.append(button)

        # グリッドの設定
        for i in range(5):
            self.master.columnconfigure(i, weight=1)

        # ラベルを配置
        self.label_var = tk.StringVar()
        self.label_var.set("画面Aです")
        label = tk.Label(self.master, textvariable=self.label_var)
        label.grid(row=1, column=0, columnspan=5, pady=10)

        # 戻るボタンを右下に配置
        back_button = tk.Button(self.master, text="戻る", command=self.show_start_page)
        back_button.grid(row=2, column=4, padx=10, pady=50, sticky="se")

        # 画面の上に配置
        self.master.lift()

    def show_start_page(self):
        # 戻るボタンが押されたときの処理
        self.master.destroy()  # 画面Aを閉じる
        self.start_page.show_first_frame()  # Start画面に戻る

    def show_question(self, question):
        # 問題ボタンが押されたときの処理
        self.label_var.set(f"問題{question}が選択されました。")
        for btn in self.buttons:
            if btn.cget("text") == question:
                btn.config(state=tk.DISABLED, bg="gray")

        # エクセル画面を表示
        excel_app, workbook = self.open_excel(self.excel_file_path)

    def open_excel(self, file_path):
        # ファイルの存在を確認
        if not os.path.exists(file_path):
            print(f"Error: File '{file_path}' not found.")
            return None

        try:
            # Excelアプリケーションを起動
            excel_app = win32.Dispatch("Excel.Application")

            # Excelファイルを開く
            workbook = excel_app.Workbooks.Open(file_path)

            # Excelウィンドウの大きさを画面いっぱいに変更
            excel_app.ActiveWindow.WindowState = 3  # xlMaximized
            excel_app.ActiveWindow.Width = excel_app.Application.Width
            excel_app.ActiveWindow.Height = excel_app.Application.Height - 30  # タイトルバーなどの高さを考慮

            # Excelウィンドウを画面の左上に移動
            excel_app.Left = 0
            excel_app.Top = 0

            # Excelウィンドウを表示
            excel_app.Visible = True

            return excel_app, workbook

        except Exception as e:
            print(f"Error: {e}")
            return None

class StartPage:
    def __init__(self, master):
        self.master = master
        self.master.title("Start画面")

        # 画面サイズを取得
        screen_width = self.master.winfo_screenwidth()
        screen_height = self.master.winfo_screenheight()

        # 画面の縦幅と横幅を取得
        width = int(screen_width * 0.5)
        height = int(screen_height * 0.5)

        # 画面の中央に配置
        x = (screen_width - width) // 2
        y = (screen_height - height) // 2
        self.master.geometry(f"{width}x{height}+{x}+{y}")

        # ボタンを縦に7つ等間隔で配置
        button_texts = ["A", "B", "C", "D", "E", "F", "G"]
        for btn_text in button_texts:
            button = tk.Button(self.master, text=f"ボタン{btn_text}", command=lambda btn=btn_text: self.show_window(btn))
            button.pack(pady=10)

    def show_window(self, btn_text):
        # ボタンが押されたときの処理
        if btn_text == "A":
            self.master.withdraw()  # Start画面を非表示にする
            window_a = tk.Toplevel(self.master)
            WindowA(window_a, self, r"C:\Users\so12r\Documents\github\tkinter_desktop\Test.xlsx")

    def show_first_frame(self):
        # Start画面を表示
        self.master.deiconify()

if __name__ == "__main__":
    root = tk.Tk()
    app = StartPage(root)
    root.mainloop()
